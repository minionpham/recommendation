# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# URL of the webpage (Spotify Daily charts Viet Nam)
url = "https://kworb.net/spotify/country/vn_daily.html"

# Send a GET request to fetch the HTML content
response = requests.get(url)
response.encoding = 'utf-8'  # Ensure the content is decoded in UTF-8
if response.status_code != 200:
    print(f"Failed to retrieve page. Status code: {response.status_code}")
    exit()

html_content = response.text

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find the table containing the data
table = soup.find('table')
if not table:
    print("Table not found on the page. Please check the page structure.")
    exit()

# Initialize a list to store data
data = []

# Initialize a counter for numerical order
num_order = 1

# Iterate through each row in the table (skipping the header row)
for row in table.find_all('tr')[1:]:  # Skip header row
    # Extract columns (name, days, T10, Pk, (x?), PkStreams, Total)
    columns = row.find_all('td')

    if len(columns) >= 7:
        try:
            # Extract name and artist from the third column (columns[2])
            name_artist = columns[2].text.strip()
            print(f"Raw name_artist: '{name_artist}'")  # Debugging line to see raw name_artist

            # Check if there is a ' - ' separating artist and track
            if " - " not in name_artist:
                print(f"Skipping row due to missing ' - ': {name_artist}")
                continue

            # Using regex to clean up possible extra spaces around the separator and split
            match = re.match(r"(.+) - (.+)", name_artist)
            if match:
                artist, name = match.groups()
                artist, name = artist.strip(), name.strip()

                # Extract track URL (validating presence of <a> tags)
                link_tags = columns[2].find_all('a')
                if len(link_tags) < 2:
                    print(f"Skipping row due to missing track URL: {row}")
                    continue

                track_url = link_tags[1]['href']
                track_id = track_url.split('/')[-1].split('.')[0]  # Extract ID

                # Append data as a tuple including numerical order
                data.append((num_order, name, artist, track_id))

                # Increment numerical order
                num_order += 1
            else:
                print(f"Skipping row due to unexpected format: {name_artist}")

        except IndexError as e:
            print(f"IndexError: {e} - Skipping row: {row}")

        except Exception as e:
            print(f"Error: {e} - Skipping row: {row}")

# Specify the CSV file path
csv_file = 'spotify_data_vn_daily_chart.csv'

# Write data to CSV file
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Order', 'Name', 'Artist', 'ID'])  # Write header
    writer.writerows(data)

print(f"CSV file '{csv_file}' with ordered data has been created successfully.")
# Out:
# Raw name_artist: 'Jung Kook - Seven (w/ Latto)'
# Raw name_artist: 'Jimin - Who'
# Raw name_artist: 'ROSÉ - number one girl'
# Raw name_artist: 'Jin - Running Wild'
# Raw name_artist: 'Jung Kook - 3D (w/ Jack Harlow)'
# Raw name_artist: 'HIEUTHUHAI - Exit Sign (w/ marzuz)'
# Raw name_artist: 'Dương Domic - Mất Kết Nối'
# Raw name_artist: 'Jung Kook - Standing Next to You'
# Raw name_artist: 'Vũ. - Bình Yên (w/ Binz)'
# Raw name_artist: 'HIEUTHUHAI - Không Thể Say'
# Raw name_artist: 'tlinh - PHÓNG ZÌN ZÌN (w/ Low G)'
# Raw name_artist: 'ROSÉ - APT. (w/ Bruno Mars)'
# Raw name_artist: 'MONO - Chăm Hoa'
# Raw name_artist: 'Puppy - Wrong Times (w/ Dangrangto)'
# Raw name_artist: 'ANH TRAI "SAY HI" - TRÀN BỘ NHỚ (w/ Dương Domic)'
# Raw name_artist: 'Lady Gaga - Die With A Smile (w/ Bruno Mars)'
# Raw name_artist: 'Da LAB - Bầu Trời Mới (w/ Minh Tốc & Lam)'
# Raw name_artist: 'Sơn Tùng M-TP - Đừng Làm Trái Tim Anh Đau'
# Raw name_artist: 'CoolKid - Sau Cơn Mưa (w/ RHYDER)'
# Raw name_artist: 'MANBO - Hẹn Gặp Em Dưới Ánh Trăng (w/ HIEUTHUHAI, HURRYKNG)'
# Raw name_artist: 'Dangrangto - NGỰA Ô (w/ TeuYungBoy, DONAL)'
# Raw name_artist: 'ANH TRAI "SAY HI" - SAO HẠNG A (w/ HIEUTHUHAI, Dương Domic, Song Luân, JSOL, Trần Đăng Dương)'
# Raw name_artist: 'V - Love Me Again'
# Raw name_artist: 'ANH TRAI "SAY HI" - KIM PHÚT, KIM GIỜ (w/ HURRYKNG, HIEUTHUHAI, Negav, Pháp Kiều, Isaac)'
# Raw name_artist: 'Vũ. - Không Yêu Em Thì Yêu Ai? (w/ Low G)'
# Raw name_artist: 'ANH TRAI "SAY HI" - HÀO QUANG (w/ RHYDER, Dương Domic, Pháp Kiều)'
# Raw name_artist: 'RHYDER - Chịu Cách Mình Nói Thua (w/ Coolkid, BAN)'
# Raw name_artist: 'HIEUTHUHAI - NOLOVENOLIFE'
# Raw name_artist: 'Wren Evans - Từng Quen (w/ itsnk)'
# Raw name_artist: 'Dangrangto - Love is'
# Raw name_artist: 'RAP VIỆT - LƯỚT TRÊN CON SÓNG (w/ Dangrangto)'
# Raw name_artist: 'HIEUTHUHAI - Nghe Như Tình Yêu'
# Raw name_artist: 'Emcee L (Da LAB) - Chuyện Đôi Ta (w/ Muộii (Starry Night))'
# Raw name_artist: 'ANH TRAI "SAY HI" - NGÁO NGƠ (w/ HIEUTHUHAI, ERIK, Anh Tú Atus, JSOL, Orange)'
# Raw name_artist: 'RAP VIỆT - QUA TỪNG KHUNG HÌNH (w/ Hustlang Robber, Ngắn)'
# Raw name_artist: 'Emcee L (Da LAB) - Sinh Ra Đã Là Thứ Đối Lập Nhau (w/ Da LAB, Badbies)'
# Raw name_artist: 'tlinh - nếu lúc đó (w/ 2pillz)'
# Raw name_artist: 'W/N - id 072019'
# Raw name_artist: '14 Casper - một đời (w/ Bon Nghiêm, buitruonglinh)'
# Raw name_artist: 'Vũ. - Những Lời Hứa Bỏ Quên (w/ Dear Jane)'
# Raw name_artist: 'Madihu - Vì Anh Đâu Có Biết (w/ Vũ.)'
# Raw name_artist: 'tlinh - HOP ON DA SHOW (w/ Low G)'
# Raw name_artist: 'Jimin - Be Mine'
# Raw name_artist: 'Minh Huy - Miên Man'
# Raw name_artist: 'GREY D - vaicaunoicokhiennguoithaydoi (w/ tlinh)'
# Raw name_artist: 'Wxrdie - Tim Anh Ghen (w/ Dangrangto, TeuYungBoy, LVK)'
# Raw name_artist: 'ANH TRAI "SAY HI" - CHÂN THÀNH (w/ RHYDER, Captain, Quang Hùng MasterD, WEAN, Ali Hoàng Dương)'
# Raw name_artist: 'Da LAB - Chạy Khỏi Thế Giới Này (w/ Phương Ly)'
# Raw name_artist: 'Ronboogz - nhắn nhủ'
# Raw name_artist: 'Low G - Simp Gái 808'
# Raw name_artist: 'ANH TRAI "SAY HI" - REGRET (w/ Quân A.P, Pháp Kiều, Quang Trung, Ali Hoàng Dương, Lâm Bảo Ngọc)'
# Raw name_artist: 'ANH TRAI "SAY HI" - TÌNH ĐẦU QUÁ CHÉN (w/ Quang Hùng MasterD, Negav, Pháp Kiều, ERIK)'
# Raw name_artist: 'Chọn gì? Chọn đi! - Say Yes (Vietnamese Version) (w/ OgeNus, PiaLinh)'
# Raw name_artist: 'WEAN - shhhhhhh.. (w/ tlinh)'
# Raw name_artist: 'Captain - Ừ Thì Chia Tay (w/ RHYDER)'
# Raw name_artist: 'V - FRI(END)S'
# Raw name_artist: 'G-DRAGON - HOME SWEET HOME (w/ TAEYANG, DAESUNG)'
# Raw name_artist: 'Wxrdie - Băng Qua Cầu Giấy (w/ RPT JasonDilla)'
# Raw name_artist: 'Vũ Cát Tường - Từng Là'
# Raw name_artist: 'AMEE - MỘNG YU (w/ RPT MCK)'
# Raw name_artist: 'HIEUTHUHAI - ngủ một mình (tình rất tình) (w/ Negav, Kewtiie)'
# Raw name_artist: 'Sơn Tùng M-TP - Âm Thầm Bên Em'
# Raw name_artist: 'Vũ Cát Tường - Mo'
# Raw name_artist: 'Ronboogz - Lan Man'
# Raw name_artist: 'Sơn Tùng M-TP - Muộn Rồi Mà Sao Còn'
# Raw name_artist: 'Sơn Tùng M-TP - Chúng Ta Của Hiện Tại'
# Raw name_artist: 'GREY D - dự báo thời tiết hôm nay mưa'
# Raw name_artist: 'JSOL - Sài Gòn Hôm Nay Mưa (w/ Hoàng Duyên)'
# Raw name_artist: 'Shartnuss - Nắng có mang em về (w/ Tr.D, Phankeo)'
# Raw name_artist: 'Olew - Rồi Ta Sẽ Ngắm Pháo Hoa Cùng Nhau'
# Raw name_artist: 'Kha - Hư không'
# Raw name_artist: 'Negav - Mình Anh Thôi'
# Raw name_artist: 'GREY D - đưa em về nhàa (w/ Chillies)'
# Raw name_artist: 'Ngô Lan Hương - Đi Giữa Trời Rực Rỡ'
# Raw name_artist: 'Low G - An Thần (w/ Thắng)'
# Raw name_artist: 'Tăng Duy Tân - Say Sóng'
# Raw name_artist: 'WEAN - BADBYE'
# Raw name_artist: 'JENNIE - Mantra'
# Raw name_artist: 'Obito - Hà Nội (w/ Shiki, VSTRA)'
# Raw name_artist: 'Lou Hoàng - Ngày Đẹp Trời Để Nói Chia Tay'
# Raw name_artist: 'RAP VIỆT - ĐÂU PHẢI VỢ ANH (w/ Dangrangto)'
# Raw name_artist: 'T.R.I - Ánh Sao Và Bầu Trời'
# Raw name_artist: 'Da LAB - Thức Giấc'
# Raw name_artist: 'Sơn Tùng M-TP - Chúng Ta Của Tương Lai'
# Raw name_artist: 'Karik - Bạn Đời (w/ GDucky)'
# Raw name_artist: 'Arcane - Ma Meilleure Ennemie - from the series Arcane League of Legends (w/ League of Legends, Stromae, Pomme)'
# Raw name_artist: 'Sơn Tùng M-TP - Buông Đôi Tay Nhau Ra'
# Raw name_artist: 'Jin - I’ll Be There'
# Raw name_artist: 'Dương Domic - Pin Dự Phòng (w/ Lou Hoàng)'
# Raw name_artist: 'Rhymastic - Lặng'
# Raw name_artist: 'Phương Ly - Anh Là Ngoại Lệ Của Em'
# Raw name_artist: 'Andiez - Suýt Nữa Thì...'
# Raw name_artist: 'Dương Domic - Chập Chờn'
# Raw name_artist: 'RPT MCK - Chìm Sâu (w/ Trung Trần)'
# Raw name_artist: 'The Weeknd - One Of The Girls (w/ JENNIE, Lily-Rose Depp)'
# Raw name_artist: '14 Casper - bao tiền một mớ bình yên? (w/ Bon Nghiêm)'
# Raw name_artist: 'JustaTee - 2AM (w/ BigDaddy)'
# Raw name_artist: 'Vũ. - Lạ Lùng'
# Raw name_artist: 'tlinh - Thích Quá Rùi Nà (w/ Trung Trần)'
# Raw name_artist: 'Kuun Đức Nam - Tình cờ yêu em (w/ Linh Thộn)'
# Raw name_artist: 'ANH TRAI "SAY HI" - QUAY ĐI QUAY LẠI (w/ HIEUTHUHAI)'
# Raw name_artist: 'Wxrdie - Bước Za Đi Xa (w/ Marlykid, Lucin3x)'
# Raw name_artist: 'MONSTAR - tình yêu chậm trễ'
# Raw name_artist: 'JustaTee - Thằng Điên (w/ Phương Ly)'
# Raw name_artist: 'UMIE - Không Yêu Xin Đừng Nói - Piano Version'
# Raw name_artist: 'Sơn Tùng M-TP - Nơi Này Có Anh'
# Raw name_artist: 'ANH TRAI "SAY HI" - ANH BIẾT RỒI (w/ RHYDER, Jmi Ko)'
# Raw name_artist: 'ANH TRAI "SAY HI" - TRÓI EM LẠI (w/ Quang Hùng MasterD)'
# Raw name_artist: 'Dangrangto - MOIEM (w/ DONAL)'
# Raw name_artist: 'Dương Domic - Tràn Bộ Nhớ'
# Raw name_artist: 'Đen - Đi Về Nhà (w/ JustaTee)'
# Raw name_artist: 'Billie Eilish - BIRDS OF A FEATHER'
# Raw name_artist: 'Đen - Lối Nhỏ (w/ Phương Anh Đào)'
# Raw name_artist: 'Vũ. - Bước Qua Mùa Cô Đơn'
# Raw name_artist: 'Vũ. - Nếu Những Tiếc Nuối'
# Raw name_artist: 'Rocky CDE - Việc Nên Làm (w/ Dangrangto, VCC Left Hand)'
# Raw name_artist: 'MONO - Em Xinh (w/ Onionn.)'
# Raw name_artist: 'W/N - 3107 3 (w/ Duongg, Nau, titie)'
# Raw name_artist: 'Wren Evans - Phóng Đổ Tim Em (w/ itsnk)'
# Raw name_artist: 'PC - 10 Ngàn Năm'
# Raw name_artist: 'Trúc Nhân - Không Ra Gì'
# Raw name_artist: 'Kay Chau Anh - Think About U'
# Raw name_artist: 'PC - Ghé Qua (w/ Dick, tofutns)'
# Raw name_artist: '52Hz - ĐỢI (SPECIAL VERSION) (w/ WEAN, RIO)'
# Raw name_artist: 'Dương Domic - Yêu Em 2 Ngày'
# Raw name_artist: 'RPT Orijinn - Don't Côi (w/ Ronboogz)'
# Raw name_artist: 'aespa - Whiplash'
# Raw name_artist: 'Wren Evans - Tò Te Tí (w/ itsnk)'
# Raw name_artist: 'JustaTee - Forget About Her'
# Raw name_artist: '52Hz - ĐỢI (Prod. RIO)'
# Raw name_artist: 'HIEUTHUHAI - Bật Nhạc Lên (w/ Harmonie)'
# Raw name_artist: 'RAP VIỆT - TRAI HỌ VŨ (w/ Gill, ICY FAMOU$)'
# Raw name_artist: 'ANH TRAI "SAY HI" - CATCH ME IF YOU CAN (w/ Quang Hùng MasterD, Negav, Công Dương, NICKY)'
# Raw name_artist: 'RPT MCK - Anh Đã Ổn Hơn'
# Raw name_artist: 'Ronboogz - Nói Dối'
# Raw name_artist: 'VSOUL - Buồn Hay Vui (w/ RPT MCK, Obito, Ronboogz, Boyzed)'
# Raw name_artist: 'ROSÉ - On The Ground'
# Raw name_artist: 'Andree Right Hand - Em iu (w/ Wxrdie, Bình Gold, 2pillz)'
# Raw name_artist: 'Dhruv - double take'
# Raw name_artist: 'Lê Hiếu - Ngày Mai Em Đi (w/ SOOBIN, Touliver)'
# Raw name_artist: 'Madihu - Có Em (w/ Low G)'
# Raw name_artist: 'Andiez - Anh Đánh Rơi Người Yêu Này (w/ AMEE)'
# Raw name_artist: 'AMEE - ex's hate me, Pt.2'
# Raw name_artist: 'Changg - Em Không Hiểu (w/ Minh Huy)'
# Raw name_artist: 'Da LAB - Thanh Xuan'
# Raw name_artist: 'NICKY - thật quá đáng.. để yêu (w/ AMEE)'
# Raw name_artist: 'SOOBIN - giá như'
# Raw name_artist: 'Kendrick Lamar - luther'
# Raw name_artist: 'Khiem - Yên Bình Có Quá Đắt Không'
# Raw name_artist: 'Andree Right Hand - Chơi Như Tụi Mỹ'
# Raw name_artist: 'Wxrdie - Trở Về (w/ JustaTee)'
# Raw name_artist: 'Obito - Đánh Đổi (w/ Shiki, RPT MCK)'
# Raw name_artist: 'Ronboogz - Anh Chỉ Muốn'
# Raw name_artist: 'Lu - chẳng giống giáng sinh (w/ Willistic)'
# Raw name_artist: '2T - Liệu Giờ (w/ Văn)'
# Raw name_artist: 'Thanh Hưng - Lao Tâm Khổ Tứ'
# Raw name_artist: 'Quang Hùng MasterD - Thủy Triều'
# Raw name_artist: 'WEAN - She Said (w/ NAOMI)'
# Raw name_artist: 'Lou Hoàng - Yêu Một Người Có Lẽ (w/ Miu Lê)'
# Raw name_artist: 'buitruonglinh - Em Không Khóc (w/ Vũ Phụng Tiên)'
# Raw name_artist: 'Shiki - 1000 Ánh Mắt (w/ Obito)'
# Raw name_artist: 'HIEUTHUHAI - TRÌNH'
# Raw name_artist: 'MIN - Có Em Chờ (w/ Mr A)'
# Raw name_artist: 'B Ray - Cao Ốc 20'
# Raw name_artist: 'RPT MCK - Chỉ Một Đêm Nữa Thôi (w/ tlinh)'
# Raw name_artist: 'Ronboogz - Khi Mà'
# Raw name_artist: 'Andiez - Chờ Đợi Có Đáng Sợ'
# Raw name_artist: 'W/N - 3 1 0 7 (w/ Duongg, Nâu)'
# Raw name_artist: 'Wren Evans - Thích Em Hơi Nhiều'
# Raw name_artist: 'LISA - Moonlit Floor'
# Raw name_artist: 'tlinh - NGÂN (w/ Low G)'
# Raw name_artist: 'ROSÉ - Gone'
# Raw name_artist: 'Wxrdie - Thèn Chóa (w/ KayC)'
# Raw name_artist: 'Vũ Phụng Tiên - Lệ Lưu Ly (w/ null)'
# Raw name_artist: 'Rapital - XTC (Xích Thêm Chút) - Remix (w/ RPT Groovie, tlinh, RPT MCK)'
# Raw name_artist: 'Thịnh Suy - Chết Trong Em'
# Raw name_artist: 'Jung Kook - Yes or No'
# Raw name_artist: 'Jin - Heart on the Window (w/ WENDY)'
# Raw name_artist: 'Tóc Tiên - Có Ai Thương Em Như Anh (w/ Touliver)'
# Raw name_artist: 'Andree Right Hand - Dân Chơi Sao Phải Khóc (w/ RHYDER, WOKEUP)'
# Raw name_artist: 'SZA - Kill Bill'
# Raw name_artist: 'Wxrdie - 29 (w/ Mason Nguyen)'
# Raw name_artist: 'RAP VIỆT - TUYẾT TRÊN PHỐ (w/ Gill)'
# Raw name_artist: 'Kai Đinh - Trái đất ôm Mặt trời (w/ GREY D, Hoàng Thùy Linh)'
# Raw name_artist: 'Binz - Cho Mình Em (w/ Đen)'
# Raw name_artist: 'buitruonglinh - Dù Cho Mai Về Sau'
# Raw name_artist: 'Wxrdie - TETVOVEN (w/ Andree Right Hand, Machiot)'
# Raw name_artist: 'HIEUTHUHAI - Không Phải Gu (w/ B Ray, Tage)'
# Raw name_artist: 'SIVAN - haydeanhduoccungemdau (w/ Kai Đinh)'
# Raw name_artist: 'PhucXp - Như Anh Đã Thấy Em (w/ Freak D)'
# Raw name_artist: 'Lynk Lee - Buồn Thì Cứ Khóc Đi'
# Raw name_artist: 'Ân ngờ - Nghe kể năm 90s (w/ Suzie MK, Zer Nguyễn)'
# Raw name_artist: 'Jin - Falling'
# Raw name_artist: 'Thịnh Suy - Thắc Mắc?'
# Raw name_artist: 'The Masked Singer - Rồi Em Sẽ Gặp Một Chàng Trai Khác (w/ HippoHappy)'
# Raw name_artist: 'ANH TRAI "SAY HI" - LOVE SAND (w/ HIEUTHUHAI, JSOL, Ali Hoàng Dương, Vũ Thịnh)'
# Raw name_artist: 'Ngọt - Cho Tôi Lang Thang (w/ Đen)'
# Raw name_artist: 'ANH TRAI "SAY HI" - I'M THINKING ABOUT YOU (w/ RHYDER, WEAN, Đức Phúc, Hùng Huỳnh, tlinh)'
# Raw name_artist: 'Đức Phúc - Ngày Đầu Sau Chia Tay'
# Raw name_artist: 'Jin - Another Level'
# CSV file 'spotify_data_vn_daily_chart.csv' with ordered data has been created successfully.
